# %%
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.common.by import By
nav = webdriver.Chrome()

#Passo 1: Pegar a Cotação do Dólar
#entrar no google
nav.get('https://www.google.com/webhp?hl=en&sa=X&ved=0ahUKEwj7tMPg0cL8AhXkLLkGHQx5CqgQPAgI')
nav.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys('cotação dólar')

nav.find_element(By.XPATH, '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)

cotacao_dolar = nav.find_element(By.XPATH, '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute('data-value')
print(cotacao_dolar)

#Passo 2: Pegar a Cotação do Euro
nav.get("https://www.google.com/")
nav.find_element(By.XPATH,
    '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys("cotação euro")
nav.find_element(By.XPATH,
    '/html/body/div[1]/div[3]/form/div[1]/div[1]/div[1]/div/div[2]/input').send_keys(Keys.ENTER)

cotacao_euro = nav.find_element(By.XPATH,
    '//*[@id="knowledge-currency__updatable-data-column"]/div[1]/div[2]/span[1]').get_attribute("data-value")
print(cotacao_euro)

#Passo 3: Pegar a Cotação do Ouro
nav.get('https://www.melhorcambio.com/ouro-hoje')

#captura do atributo 'value'(valor) do elemento
cotacao_ouro = nav.find_element(By.XPATH, '//*[@id="comercial"]').get_attribute('value')
cotacao_ouro = cotacao_ouro.replace(',', '.')
print(cotacao_ouro)

nav.quit()
# Out:
# 5.2214
# 5.6441
# 322.49

# %%
#Passo 4: Atualizar a base

#etapa 1: Importar Tabela
import pandas as pd
tabela = pd.read_excel('Produtos.xlsx')
display(tabela)
# Out:
#          Produtos  Preço Original  Moeda  Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar        5          4999.95    1.40
# 1   Carro Renault         4500.00   Euro        6         27000.00    2.00
# 2   Notebook Dell          899.99  Dólar        5          4499.95    1.70
# 3          IPhone          799.00  Dólar        5          3995.00    1.70
# 4      Carro Fiat         3000.00   Euro        6         18000.00    1.90
# 5  Celular Xiaomi          480.48  Dólar        5          2402.40    2.00
# 6        Joia 20g           20.00   Ouro      350          7000.00    1.15
#
#    Preço de Venda
# 0        6999.930
# 1       54000.000
# 2        7649.915
# 3        6791.500
# 4       34200.000
# 5        4804.800
# 6        8050.000

# %%
#Passo 5: Recalcular os preços
#etapa 1: Atualizando tabela c/ o método loc
tabela.loc[tabela['Moeda'] == 'Dólar', 'Cotação'] = float(cotacao_dolar)
tabela.loc[tabela['Moeda'] == 'Euro', 'Cotação'] = float(cotacao_euro)
tabela.loc[tabela['Moeda'] == 'Ouro', 'Cotação'] = float(cotacao_ouro)

#preço de compra = tabela['Cotação'] * tabela['Preço Original']
tabela['Preço de Compra'] = tabela['Preço Original'] * tabela['Cotação']

#preço de venda = preço de compra * margem

tabela['Preço de Venda'] = tabela['Preço de Compra'] * tabela['Margem']
display(tabela)
# Out:
#          Produtos  Preço Original  Moeda   Cotação  Preço de Compra  Margem  \
# 0    Câmera Canon          999.99  Dólar    5.2214      5221.347786    1.40
# 1   Carro Renault         4500.00   Euro    5.6441     25398.450000    2.00
# 2   Notebook Dell          899.99  Dólar    5.2214      4699.207786    1.70
# 3          IPhone          799.00  Dólar    5.2214      4171.898600    1.70
# 4      Carro Fiat         3000.00   Euro    5.6441     16932.300000    1.90
# 5  Celular Xiaomi          480.48  Dólar    5.2214      2508.778272    2.00
# 6        Joia 20g           20.00   Ouro  322.4900      6449.800000    1.15
#
#    Preço de Venda
# 0     7309.886900
# 1    50796.900000
# 2     7988.653236
# 3     7092.227620
# 4    32171.370000
# 5     5017.556544
# 6     7417.270000

# %%
#Passo 6: Exportar a base atualizada
tabela.to_excel('Produtos.xlsx')
